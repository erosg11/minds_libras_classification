# %%
from tools import OUT_PATH, open_meta_df
import pandas as pd
import numpy as np
from skopt import BayesSearchCV
from sklearn.base import clone
from sklearn.neighbors import KNeighborsClassifier
from tqdm.auto import tqdm
from skopt.space import Integer, Categorical, Real
from pprint import pprint
from warnings import filterwarnings
from joblib import dump
from KMeansCustomEstimator import KMeansCustomEstimator
from functools import reduce
from operator import mul
filterwarnings("ignore")

# %%
model_name = 'KNN'

# %%
meta_df = open_meta_df()
video_id = np.load(OUT_PATH / 'video_id.npy')
landmarks = np.load(OUT_PATH / 'landmarks.npy')
train_idx = np.load(OUT_PATH / 'train_idx.npy')
test_idx = np.load(OUT_PATH / 'test_idx.npy')
meta_df.head()
# Out:
#                                             filename  \
# 0  /media/eros/BackupMae/datasets/Minds/Sinalizad...
# 1  /media/eros/BackupMae/datasets/Minds/Sinalizad...
# 2  /media/eros/BackupMae/datasets/Minds/Sinalizad...
# 3  /media/eros/BackupMae/datasets/Minds/Sinalizad...
# 4  /media/eros/BackupMae/datasets/Minds/Sinalizad...
#
#                          stem  pose_id       word  sinalizador  repetition
# 0  01AcontecerSinalizador01-1        1  Acontecer            1           1
# 1  01AcontecerSinalizador01-2        1  Acontecer            1           2
# 2  01AcontecerSinalizador01-3        1  Acontecer            1           3
# 3  01AcontecerSinalizador01-4        1  Acontecer            1           4
# 4  01AcontecerSinalizador01-5        1  Acontecer            1           5

# %%
landmarks.shape
# Out:
# (147205, 33, 3)

# %%
observations = reduce(mul, landmarks.shape[1:])

stacked_train_landmarks = [landmarks[video_id == i].reshape((-1, observations))  for i in train_idx]
stacked_test_landmarks = [landmarks[video_id == i].reshape((-1, observations)) for i in test_idx]

classes = meta_df['pose_id'].values

y_train = classes[train_idx]
y_test = classes[test_idx]
observations
# Out:
# 99

# %%
len(y_train), len(y_test), len(y_train) + len(y_test), len(classes)
# Out:
# (793, 265, 1058, 1058)

# %%
opt = BayesSearchCV(
    KMeansCustomEstimator(
        KNeighborsClassifier,
        two_dimensions=False,
        kmeans_keys=('n_clusters', ),
        estimator_keys=('n_neighbors', 'weights'),
        n_clusters=8,
        n_neighbors=5,
        weights='uniform',
    ),
    {
        'estimator': Categorical([KNeighborsClassifier]),
        'two_dimensions': Categorical([False]),
        'kmeans_keys': Categorical([frozenset(['n_clusters'])]),
        'estimator_keys': Categorical([frozenset(['n_neighbors', 'weights'])]),
        'n_clusters': Integer(1, 50),
        'n_neighbors': Integer(1, 100),
        'weights': Categorical(['uniform', 'distance']),
    },
    n_iter=100,
    random_state=42,
    cv=3,
    n_jobs=-1,
    verbose=0,
)
opt.fit(stacked_train_landmarks, y_train)
opt.best_score_
# Out:
# 0.7364684581665714

# %%
opt.best_params_
# Out:
# OrderedDict([('estimator',
#               sklearn.neighbors._classification.KNeighborsClassifier),
#              ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#              ('kmeans_keys', frozenset({'n_clusters'})),
#              ('n_clusters', 1),
#              ('n_neighbors', 1),
#              ('two_dimensions', False),
#              ('weights', 'uniform')])

# %%
estimator = clone(opt.best_estimator_)

# %%
# %%time
estimator.fit(stacked_train_landmarks, y_train)
train_score = estimator.score(stacked_train_landmarks, y_train) 
test_score = estimator.score(stacked_test_landmarks, y_test)
# Out:
# CPU times: user 25.1 s, sys: 454 ms, total: 25.6 s
# Wall time: 1.64 s

# %%
print('Acurácia de treino:', train_score, '\nAcurácia de teste:', test_score)
# Out:
# Acurácia de treino: 1.0
# Acurácia de teste: 0.8188679245283019

# %%
opt.cv_results_
# Out:
# {'mean_fit_time': array([1.23480074, 2.99152446, 1.58220522, 2.50019217, 2.33190815,
#         0.91289926, 2.62146219, 2.59780844, 1.48579327, 1.05034963,
#         3.01482765, 0.29654638, 0.29834994, 0.29294403, 0.29708076,
#         1.29625336, 2.99741379, 0.28895871, 2.71668323, 0.29262249,
#         0.29144669, 0.31887396, 0.38354246, 0.29454843, 2.94306922,
#         0.29488126, 0.29710539, 0.2942431 , 2.94818147, 0.29107912,
#         0.29238868, 3.01382287, 2.91250571, 0.30385955, 2.96678305,
#         1.2550288 , 0.48572739, 0.29571907, 0.29346498, 0.29361471,
#         0.29425041, 2.94270444, 1.6209271 , 0.37858343, 2.96806407,
#         0.60827645, 1.53551658, 2.7954603 , 1.90306012, 1.91735466,
#         1.42145022, 2.04934295, 2.74395084, 2.79175417, 2.36548034,
#         2.5220743 , 2.14684335, 2.33765133, 0.29662275, 1.993891  ,
#         2.98246829, 0.29829049, 0.29467607, 0.29193099, 1.3249778 ,
#         1.61173145, 1.41867224, 2.2880067 , 2.59126202, 1.97480122,
#         2.17543674, 2.97595239, 1.1442167 , 2.88483723, 1.40811555,
#         2.37084556, 0.7696925 , 1.60938311, 0.28952146, 2.20297782,
#         0.30035265, 2.32542356, 0.28924243, 2.92428692, 0.2903769 ,
#         1.75717862, 1.47635516, 2.62271961, 0.29136221, 0.93929013,
#         2.99104428, 1.96229982, 0.29256225, 2.18485546, 1.10298284,
#         0.93398054, 0.97216026, 2.23828292, 2.41301584, 2.40904021]),
#  'std_fit_time': array([0.01805939, 0.04488471, 0.02028028, 0.02090627, 0.06299345,
#         0.02843193, 0.03456266, 0.06216108, 0.00637719, 0.00876927,
#         0.08692138, 0.00384041, 0.00705381, 0.00433981, 0.00172474,
#         0.02323857, 0.0772456 , 0.00276721, 0.00505374, 0.00232696,
#         0.00291842, 0.01725752, 0.01131308, 0.00118983, 0.11409231,
#         0.00378792, 0.00867109, 0.00326031, 0.04867314, 0.00318019,
#         0.00209165, 0.01675891, 0.04668191, 0.0117972 , 0.04872234,
#         0.04459186, 0.01209236, 0.00755544, 0.00625394, 0.0056582 ,
#         0.00333947, 0.0362931 , 0.03303072, 0.0028656 , 0.02552324,
#         0.00594144, 0.00572777, 0.06821857, 0.01785445, 0.01800592,
#         0.01703753, 0.01574763, 0.07631717, 0.02629062, 0.04519048,
#         0.07656672, 0.00779435, 0.04837292, 0.00252325, 0.02756252,
#         0.05561031, 0.00774677, 0.00131633, 0.00271488, 0.01373601,
#         0.02781502, 0.03934982, 0.00903487, 0.04858685, 0.02742902,
#         0.02195892, 0.0123887 , 0.01273452, 0.03128873, 0.02697577,
#         0.00704191, 0.01207121, 0.01924352, 0.00402555, 0.08077009,
#         0.01275835, 0.02817271, 0.0032141 , 0.07012821, 0.00243385,
#         0.04976523, 0.01925049, 0.0361749 , 0.00443735, 0.01758765,
 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>,
#                     <class 'sklearn.neighbors._classification.KNeighborsClassifier'>],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_estimator_keys': masked_array(data=[frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'}),
#                     frozenset({'n_neighbors', 'weights'})],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kmeans_keys': masked_array(data=[frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'}),
#                     frozenset({'n_clusters'}), frozenset({'n_clusters'})],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_clusters': masked_array(data=[16, 48, 22, 40, 36, 10, 44, 42, 21, 13, 50, 1, 1, 1, 1,
#                     18, 50, 1, 45, 1, 1, 1, 2, 1, 50, 1, 1, 1, 50, 1, 1,
#                     50, 50, 1, 50, 17, 3, 1, 1, 1, 1, 49, 24, 2, 50, 5, 22,
#                     46, 29, 30, 20, 32, 45, 47, 38, 41, 34, 38, 1, 31, 50,
#                     1, 1, 1, 18, 24, 20, 37, 42, 31, 35, 50, 15, 50, 20,
#                     39, 8, 24, 1, 35, 1, 38, 1, 50, 1, 26, 21, 43, 1, 11,
#                     50, 31, 1, 35, 14, 11, 11, 37, 40, 39],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_neighbors': masked_array(data=[67, 87, 20, 53, 90, 80, 60, 33, 39, 58, 1, 1, 21, 1, 1,
#                     1, 7, 4, 2, 1, 2, 2, 100, 2, 100, 2, 2, 2, 14, 47, 2,
#                     74, 25, 12, 45, 1, 2, 3, 1, 1, 1, 1, 1, 1, 3, 1, 5, 1,
#                     1, 4, 100, 74, 4, 2, 1, 1, 1, 3, 35, 5, 56, 66, 88, 25,
#                     50, 21, 100, 70, 40, 54, 90, 100, 78, 21, 8, 10, 16,
#                     36, 36, 26, 51, 9, 91, 73, 68, 80, 64, 1, 100, 30, 87,
#                     13, 57, 100, 6, 92, 46, 1, 1, 3],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_two_dimensions': masked_array(data=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_weights': masked_array(data=['distance', 'distance', 'distance', 'uniform',
#                     'distance', 'distance', 'uniform', 'uniform',
#                     'distance', 'distance', 'distance', 'uniform',
#                     'uniform', 'uniform', 'distance', 'distance',
#                     'uniform', 'uniform', 'uniform', 'distance',
#                     'distance', 'distance', 'distance', 'distance',
#                     'uniform', 'distance', 'distance', 'distance',
#                     'distance', 'distance', 'distance', 'uniform',
#                     'distance', 'distance', 'uniform', 'uniform',
#                     'distance', 'distance', 'uniform', 'uniform',
#                     'uniform', 'distance', 'distance', 'uniform',
#                     'distance', 'uniform', 'distance', 'distance',
#                     'distance', 'uniform', 'uniform', 'uniform',
#                     'distance', 'uniform', 'distance', 'distance',
#                     'distance', 'distance', 'uniform', 'distance',
#                     'distance', 'uniform', 'uniform', 'distance',
#                     'uniform', 'uniform', 'distance', 'distance',
#                     'distance', 'distance', 'uniform', 'distance',
#                     'uniform', 'uniform', 'uniform', 'distance',
#                     'distance', 'uniform', 'distance', 'distance',
#                     'uniform', 'uniform', 'distance', 'distance',
#                     'distance', 'distance', 'uniform', 'distance',
#                     'uniform', 'distance', 'uniform', 'distance',
#                     'distance', 'distance', 'distance', 'distance',
#                     'distance', 'uniform', 'uniform', 'uniform'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 16),
#                ('n_neighbors', 67),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 48),
#                ('n_neighbors', 87),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 22),
#                ('n_neighbors', 20),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 40),
#                ('n_neighbors', 53),
#                ('two_dimensions', False),
#                ('weights', 'uniform')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 36),
#                ('n_neighbors', 90),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 10),
#                ('n_neighbors', 80),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 44),
#                ('n_neighbors', 60),
#                ('two_dimensions', False),
#                ('weights', 'uniform')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 42),
#                ('n_neighbors', 33),
#                ('two_dimensions', False),
#                ('weights', 'uniform')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 21),
#                ('n_neighbors', 39),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 13),
#                ('n_neighbors', 58),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 50),
#                ('n_neighbors', 1),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 1),
#                ('n_neighbors', 1),
#                ('two_dimensions', False),
#                ('weights', 'uniform')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 1),
#                ('n_neighbors', 21),
#                ('two_dimensions', False),
#                ('weights', 'uniform')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 1),
#                ('n_neighbors', 1),
#                ('two_dimensions', False),
#                ('weights', 'uniform')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 1),
#                ('n_neighbors', 1),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 18),
#                ('n_neighbors', 1),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 50),
#                ('n_neighbors', 7),
#                ('two_dimensions', False),
#                ('weights', 'uniform')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 1),
#                ('n_neighbors', 4),
#                ('two_dimensions', False),
#                ('weights', 'uniform')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 45),
#                ('n_neighbors', 2),
#                ('two_dimensions', False),
#                ('weights', 'uniform')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 1),
#                ('n_neighbors', 1),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 1),
#                ('n_neighbors', 2),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 1),
#                ('n_neighbors', 2),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 2),
#                ('n_neighbors', 100),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 1),
#                ('n_neighbors', 2),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 50),
#                ('n_neighbors', 100),
#                ('two_dimensions', False),
#                ('weights', 'uniform')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 1),
#                ('n_neighbors', 2),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 1),
#                ('n_neighbors', 2),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 1),
#                ('n_neighbors', 2),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 50),
#                ('n_neighbors', 14),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 1),
#                ('n_neighbors', 47),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 1),
#                ('n_neighbors', 2),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 50),
#                ('n_neighbors', 74),
#                ('two_dimensions', False),
#                ('weights', 'uniform')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 50),
#                ('n_neighbors', 25),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 1),
#                ('n_neighbors', 12),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
# ...
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 1),
#                ('n_neighbors', 36),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 35),
#                ('n_neighbors', 26),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 1),
#                ('n_neighbors', 51),
#                ('two_dimensions', False),
#                ('weights', 'uniform')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 38),
#                ('n_neighbors', 9),
#                ('two_dimensions', False),
#                ('weights', 'uniform')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 1),
#                ('n_neighbors', 91),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 50),
#                ('n_neighbors', 73),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 1),
#                ('n_neighbors', 68),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 26),
#                ('n_neighbors', 80),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 21),
#                ('n_neighbors', 64),
#                ('two_dimensions', False),
#                ('weights', 'uniform')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 43),
#                ('n_neighbors', 1),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 1),
#                ('n_neighbors', 100),
#                ('two_dimensions', False),
#                ('weights', 'uniform')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 11),
#                ('n_neighbors', 30),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 50),
#                ('n_neighbors', 87),
#                ('two_dimensions', False),
#                ('weights', 'uniform')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 31),
#                ('n_neighbors', 13),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 1),
#                ('n_neighbors', 57),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 35),
#                ('n_neighbors', 100),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 14),
#                ('n_neighbors', 6),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 11),
#                ('n_neighbors', 92),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 11),
#                ('n_neighbors', 46),
#                ('two_dimensions', False),
#                ('weights', 'distance')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 37),
#                ('n_neighbors', 1),
#                ('two_dimensions', False),
#                ('weights', 'uniform')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 40),
#                ('n_neighbors', 1),
#                ('two_dimensions', False),
#                ('weights', 'uniform')]),
#   OrderedDict([('estimator',
#                 sklearn.neighbors._classification.KNeighborsClassifier),
#                ('estimator_keys', frozenset({'n_neighbors', 'weights'})),
#                ('kmeans_keys', frozenset({'n_clusters'})),
#                ('n_clusters', 39),
#                ('n_neighbors', 3),
#                ('two_dimensions', False),
#                ('weights', 'uniform')])],
#  'split0_test_score': array([0.27169811, 0.3245283 , 0.29811321, 0.2       , 0.3245283 ,
#         0.29811321, 0.20754717, 0.23773585, 0.2490566 , 0.2754717 ,
#         0.69433962, 0.71698113, 0.17735849, 0.71698113, 0.71698113,
#         0.51320755, 0.35849057, 0.44528302, 0.50566038, 0.71698113,
#         0.71698113, 0.71698113, 0.42264151, 0.71698113, 0.23018868,
#         0.71698113, 0.71698113, 0.71698113, 0.34716981, 0.37735849,
#         0.71698113, 0.21509434, 0.35849057, 0.50566038, 0.21886792,
#         0.4754717 , 0.51320755, 0.62264151, 0.71698113, 0.71698113,
#         0.71698113, 0.67169811, 0.54339623, 0.67924528, 0.60377358,
#         0.38113208, 0.45660377, 0.64528302, 0.59622642, 0.44150943,
#         0.19622642, 0.22641509, 0.58113208, 0.51320755, 0.66037736,
#         0.64528302, 0.61886792, 0.58490566, 0.16226415, 0.49811321,
#         0.2754717 , 0.16603774, 0.1509434 , 0.41132075, 0.21132075,
#         0.25283019, 0.30566038, 0.27924528, 0.26415094, 0.27169811,
#         0.17358491, 0.3245283 , 0.19622642, 0.26037736, 0.32830189,
#         0.4754717 , 0.2754717 , 0.23396226, 0.37358491, 0.30943396,
#         0.19622642, 0.31320755, 0.39245283, 0.3509434 , 0.36603774,
#         0.30943396, 0.21132075, 0.66792453, 0.13584906, 0.23773585,
#         0.21886792, 0.3509434 , 0.39622642, 0.30188679, 0.36603774,
#         0.24528302, 0.2490566 , 0.63018868, 0.66037736, 0.47924528]),
#  'split1_test_score': array([0.25      , 0.25757576, 0.3219697 , 0.20454545, 0.25      ,
#         0.24242424, 0.23106061, 0.25      , 0.27651515, 0.24621212,
#         0.62878788, 0.72348485, 0.19318182, 0.72348485, 0.72348485,
#         0.51893939, 0.31818182, 0.46969697, 0.47727273, 0.72348485,
#         0.72348485, 0.72348485, 0.46212121, 0.72348485, 0.16666667,
#         0.72348485, 0.72348485, 0.72348485, 0.37121212, 0.39772727,
#         0.72348485, 0.21212121, 0.32954545, 0.45075758, 0.23863636,
#         0.38588241, 0.45775681, 0.64817515, 0.61793406, 0.42747284,
#         0.18157042, 0.21309796, 0.56871069, 0.52839241, 0.66204498,
#         0.64943777, 0.63179436, 0.59522108, 0.16772441, 0.49937107,
#         0.31657137, 0.16266914, 0.15006194, 0.41109682, 0.20806651,
#         0.23326663, 0.26224033, 0.29762722, 0.31406042, 0.29006099,
#         0.18538689, 0.30388317, 0.19293406, 0.25850962, 0.30009053,
#         0.4438441 , 0.29005622, 0.22318944, 0.3934677 , 0.31400324,
#         0.16641891, 0.30010959, 0.39344387, 0.32531447, 0.39095197,
#         0.27486183, 0.20680389, 0.66961121, 0.16649514, 0.25348771,
#         0.21184486, 0.36319325, 0.39848961, 0.27865923, 0.39347723,
#         0.23958929, 0.24968553, 0.6431437 , 0.65194397, 0.4804555 ]),
#  'std_test_score': array([0.01512273, 0.04241314, 0.01124606, 0.02257525, 0.03179172,
#         0.03561235, 0.0188786 , 0.00656857, 0.0205186 , 0.01588275,
#         0.04230205, 0.02311343, 0.00849395, 0.02311343, 0.02311343,
#         0.00391333, 0.02798901, 0.02399317, 0.03627916, 0.02311343,
#         0.02311343, 0.02311343, 0.02651194, 0.02311343, 0.03434996,
#         0.02311343, 0.02311343, 0.02311343, 0.03733569, 0.01060807,
#         0.02311343, 0.02076221, 0.03121331, 0.02277031, 0.01152721,
#         0.01027749, 0.02319594, 0.04163637, 0.02311343, 0.02311343,
#         0.02311343, 0.02477137, 0.01444548, 0.04152924, 0.01536114,
#         0.00572755, 0.00623908, 0.03871393, 0.01534962, 0.0135868 ,
#         0.02682502, 0.01680391, 0.0426665 , 0.04611296, 0.00629697,
#         0.0341473 , 0.02208353, 0.02431573, 0.01895415, 0.02166779,
#         0.0447437 , 0.01108374, 0.0201128 , 0.00464189, 0.0141065 ,
#         0.01665697, 0.04469038, 0.01596984, 0.03793647, 0.03071467,
#         0.02176648, 0.05011174, 0.02023749, 0.00132069, 0.02621626,
#         0.03570638, 0.01495091, 0.0132364 , 0.01414405, 0.01428767,
#         0.02808196, 0.01424619, 0.01547982, 0.04836875, 0.0192391 ,
#         0.02892663, 0.00444594, 0.00629951, 0.0285297 , 0.01155967,
#         0.0222118 , 0.00879891, 0.01400926, 0.03639148, 0.01994956,
#         0.01748031, 0.00928902, 0.01666177, 0.00671762, 0.00085575]),
#  'rank_test_score': array([ 76,  61,  59,  86,  66,  77,  83,  79,  70,  75,  16,   1,  93,
#           1,   1,  32,  55,  39,  33,   1,   1,   1,  42,   1,  87,   1,
#           1,   1,  52,  49,   1,  84,  53,  38,  81,  36,  34,  20,   1,
#           1,   1,  17,  30,  15,  26,  51,  40,  23,  27,  43,  95,  88,
#          29,  31,  19,  22,  25,  28,  96,  35,  57,  99, 100,  44,  90,
#          82,  72,  65,  58,  67,  94,  62,  92,  73,  64,  41,  68,  85,
#          47,  60,  98,  63,  48,  56,  50,  71,  91,  18,  97,  74,  89,
#          54,  45,  69,  46,  80,  78,  24,  21,  37], dtype=int32)}

# %%
dump(opt.cv_results_, OUT_PATH / f'scores/{model_name}_scores.h5', compress=9)
dump(estimator, OUT_PATH / f'Models/{model_name}.h5', compress=9)
# Out:
# ['Outs/Models/KNN.h5']
